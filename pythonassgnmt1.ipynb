# %% [markdown]
# 1. What is Python, and why is it popular?
#
#     Python is a high-level, interpreted programming language.Python is widely used in various fields, including data science, artificial intelligence (AI), machine learning (ML), automation, and cybersecurity.
#     ->Python is easy to learn because its syntax is simple and feels like English.A massive community supports it with tons of ready-to-use libraries like NumPy, Pandas, and Django, making development faster.
# 2.What is an interpreter in Python?
#
#     Interpreter translates high-level Python code into machine-readable instructions at runtime.An interpreter in Python is a program that executes Python code line by line instead of compiling the entire program at once (like C or Java compilers do).
# 3.What are pre-defined keywords in Python?
#
#     In Python there are certain words which cannot be used as variable names,function names and identifiers because they are python keywords which have special meaning These keywords help define the structure and syntax of Python programs.
#
#     ->examples of python keywords: if, elif, else, match, case,	for, while, break, continue, def, return, yield, lambda, def, True, False, None and many more.
# 4.Can keywords be used as variable names?
#
#     No, Python keywords cannot be used as variable names because they have predefined meanings and are reserved for specific purposes in the language.
# 5. What is mutability in Python?
#
#     Mutability in python means whether the value of the object can be changed or not after the creation of the object.
#     ->List,Dictionary,Set are mutable objects in Python.
# 6.Why are lists mutable, but tuples are immutable?
#
#     List store references to elements, meaning their contents can change.whereas tuples store fixed values, so their contents cannot change.
# 7. What is the difference between “==” and “is” operators in Python?
#
#     In Python, ==(Equality) and is(Identity) are both used for comparisons, but they work differently. == compares values of 2 objects whereas is checks if two variables point to the same object in memory.
# 8. What are logical operators in Python?
#
#     Logical operators in Python are used to combine conditional statements and return True or False based on conditions.The logical operators in Python are and,or,not. and,returns True if both conditions are True.or,returns True if at least one condition is True.not, reverses the result (True becomes False, and vice versa).
# 9. What is type casting in Python?
#
#     Type casting in Python means converting one data type into another.
# 10. What is the difference between implicit and explicit type casting?
#
#     Implicit Type Casting is automatic conversion of one data type to another  by Python.There is risk of data loss in Implicit type casting.whereas in Explicit Type Casting there is manual conversion of one data type to another by the programmer and there is risk of data loss.
# 11.What is the purpose of conditional statements in Python?
#
#     Conditional statements allow a program to make decisions based on conditions. They help control the flow of execution by executing different blocks of code depending on whether a condition is True or False.we use conditional statments for desicion making that is to run different code based on condition.
# 12. How does the elif statement work?
#
#     The elif statement is used when you need to check multiple conditions in a sequence. these work when there are multiple if statements but stops checking once a condition is True.these elif statement is more efficient than using multiple if statements separately.
# 13. What is the difference between for and while loop?
#
#     for  loop is used when the number of iterations are known, whereas while loop is used when the iterations are unknown.for loop iterates over a sequence where as while loop runs as long as the condition is true.There is a risk of infinite loop in the while loop when the condition never becomes False.
# 14.Describe a scenario where a while loop is more suitable than a for loop.
#
#     The best scenario where a while loop is more suitable than a for loop is building a login system that keeps asking for the correct password until the user enters it correctly. Here, we don't know how many attempts the user will take, so a while loop is the best choice.The loop keeps running until the user enters the correct password.If the user enters the correct password on the first try, the loop runs only once.If they keep entering the wrong password, the loop continues indefinitely until they enter the correct one.A for loop is not ideal here because we don’t know how many times the user will need to enter the password.If we set a for loop with a fixed number of attempts, the user might still want more chances

# %%
#1. Write a Python program to print "Hello, World!"
'''
print("Hello, World!")
'''
#2. Write a Python program that displays your name and age.
'''
name=amaan shafi hyder
age="20"
print(name)
print(age)
'''
#3.Write code to print all the pre-defined keywords in Python using the keyword library
'''
import keyword
keyword_list=keyword.kwlist
for i in keyword_list:
    print(i)
'''
#4. Write a program that checks if a given word is a Python keyword
'''
import keyword
word=input("enter a word")
if keyword.iskeyword(word):
    print(f"{word} is a keyword")
else:
    print(f"{word} is not a keyword")
'''
#5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each
'''
lis=[1,"alice",2.3,2+3j]
print("original list:" ,lis)
mytuple=(1,"alice",2.3,2+3j)
print("original tuple:" ,mytuple)
lis[1]="bob"
print("updated list:" ,lis)
mytuple[1]="bob"
print("updated tuple:" ,mytuple)#tuple is immutable,hence it will throw an error
'''
#6.Write a function to demonstrate the behavior of mutable and immutable arguments
'''
def modify_values(immutable_arg, mutable_arg):
    immutable_arg += 10
    print(f"Inside function (immutable): {immutable_arg}")
    mutable_arg.append(4)  # Modifying a mutable argument (list)
    print(f"Inside function (mutable): {mutable_arg}")
num = 5 # Immutable argument (integer)
numbers = [1, 2, 3] # Mutable argument (list)
modify_values(num, numbers)
# Check values outside the function
print(f"Outside function (immutable): {num}")
print(f"Outside function (mutable): {numbers}")
'''
#7.Write a program that performs basic arithmetic operations on two user-input numbers.
'''
num1=float(input("enter first number"))
num2=float(input("enter second number"))
add=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2 if num2 != 0 else "Undefined (division by zero)"
modulus = num1 % num2 if num2 != 0 else "Undefined (modulus by zero)"

print(f"addition of {num1} and {num2} is {add}")
print(f"subtraction of {num1} and {num2} is {sub}")
print(f"multiplication of {num1} and {num2} is {mul}")
print(f"division of {num1} and {num2} is {div}")
print(f"modulus of {num1} and {num2} is {modulus}")
'''
#8.Write a program to demonstrate the use of logical operators.
'''
num1=float(input("enter first number"))
num2=float(input("enter second number"))
add_op= (num1>0 and num2>0)# True if both numbers are positive
or_op= (num1==0 or num2==0)#true if at least one number is zero
not_op=not(num1< 0 or num2 < 0)#True if neither number is negative
print(f"addition of {num1} and {num2} is {add_op}")
print(f"addition of {num1} and {num2} is {or_op}")
print(f"addition of {num1} and {num2} is {not_op}")
'''
#9. Write a Python program to convert user input from string to integer, float, and boolean types
'''
num_str=input("enter a number")
num_int=int(num_str)
num_float=float(num_str)
num_bool=bool(num_str)
print(f"string: {num_str}")
print(f"integer: {num_int}")
print(f"float: {num_float}")
print(f"boolean: {num_bool}")
'''
#10. Write code to demonstrate type casting with list elements.
'''
lis=["1","2","3"]
print(lis)
lis=[int(i) for i in lis]
print(lis)
'''
#11.Write a program that checks if a number is positive, negative, or zero.
'''
num=float(input("enter a number"))
if num>0:
    print(f"{num} is positive")
elif num<0:
    print(f"{num} is negative")
else:
    print(f"{num} is zero")
'''
#12. Write a for loop to print numbers from 1 to 10.
'''
for i in range(1,11):
    print(i)
'''
#13. Write a Python program to find the sum of all even numbers between 1 and 50.
'''
sum=0
for i in range(2,51,2):
    sum+=i
print(sum)
'''
#14.Write a program to reverse a string using a while loop
'''
string=input("enter a string")
reversed_string=""
length=len(string)
while length>0:
    reversed_string+=string[length-1]
    length-=1
print(reversed_string)
'''
#15.Write a Python program to calculate the factorial of a number provided by the user using a while loop.
'''
num=int(input("enter a number"))
factorial=1
while num>0:
    factorial*=num
    num-=1
print(factorial)
'''
